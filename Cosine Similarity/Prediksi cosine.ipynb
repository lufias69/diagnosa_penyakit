# %%
from prediksi import prediksi as pds

# %%
from prediksi import prediksi as pds
#prediksi(diagnosa, n=10, delimiter = deli)
a = "Abortus. Kelahiran prematur atau lahir mati. Abses organ."
x = pds.prediksi(a, metode = "cosine", delimiter = ["."])
print(x['penyakit'])
print(x['detail penyakit'])
print(x['jenis infeksi'])
print(x['similarity'])
# Out:
# Listeriosis
# Janin
# Infeksi bakteri
# 1.0

# %%
print(x["gejala"])
x['data']
# Out:
# abortus kelahiran prematur kelahiran_prematur lahir mati lahir_mati abses organ abses_organ
#                                   penyakit  \
# 17                             Listeriosis
# 36                                 Sifilis
# 0                                   Antrax
# 121                                    DBD
# 113                         Pyelonephritis
# 114                                 Gonore
# 115                                Sifilis
# 116                                Typhoid
# 117                            Shigellosis
# 118                              Pertussis
# 119                          Herpes zoster
# 120                   Moluscum contagiosum
# 122                                  Kusta
# 111                             Filariasis
# 123            Pelvis inflammatory disease
# 124                    Dermatitis venenata
# 125                                Sisitis
# 126                        Antrax Kutaneus
# 127                      Antrax intestinal
# ...

# %%
x = pds.prediksi(a, metode = "knn", delimiter = ["sa"])
print(x['penyakit'])
print(x['detail penyakit'])
# Out:
# Listeriosis
# Janin
